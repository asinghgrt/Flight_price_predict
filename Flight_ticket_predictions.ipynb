# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import Lasso

# %%
data=pd.read_csv('/content/Data_Train[1].csv')

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
data.dropna(how='any',inplace=True)

# %%
# Out:
# <ipython-input-186-52d55bee98d7>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.cov('price','Airline')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-186-52d55bee98d7> in <cell line: 1>()
# ----> 1 data.cov('price','Airline')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in cov(self, min_periods, ddof, numeric_only)
#   10468
#   10469         if notna(mat).all():
# > 10470             if min_periods is not None and min_periods > len(mat):
#   10471                 base_cov = np.empty((mat.shape[1], mat.shape[1]))
#   10472                 base_cov.fill(np.nan)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
data['Airline'].value_counts()
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
data['Source'].value_counts()
# Out:
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %%
data['Destination'].value_counts()
# Out:
# Cochin       4536
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %%
data['Total_Stops'].value_counts()
# Out:
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
data['Additional_Info'].value_counts()
# Out:
# No info                         8344
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %% [markdown]
# Labellling data to numeric types:

# %%
data.replace({'Airline':{'Jet Airways':0,'IndiGo':1,'Air India':2,'Multiple carriers':3,'SpiceJet':4,'Vistara':5,'Air Asia':6,'GoAir':7,'Multiple carriers Premium economy':8,'Jet Airways Business':9,
'Vistara Premium economy':10,
'Trujet':11}},inplace=True)

# %%
data.head()
# Out:
#    Airline Date_of_Journey    Source Destination                  Route  \
# 0        1      24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1        2       1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2        0       9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3        1      12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4        1      01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
data.replace({'Source':{'Delhi':0,
'Kolkata':1,
'Banglore':2,
'Mumbai':3,
'Chennai':4}},inplace=True)

# %%
data.head()
# Out:
#    Airline Date_of_Journey  Source Destination                  Route  \
# 0        1      24/03/2019       2   New Delhi              BLR ? DEL
# 1        2       1/05/2019       1    Banglore  CCU ? IXR ? BBI ? BLR
# 2        0       9/06/2019       0      Cochin  DEL ? LKO ? BOM ? COK
# 3        1      12/05/2019       1    Banglore        CCU ? NAG ? BLR
# 4        1      01/03/2019       2   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# marking of destnation:
# Destination':'Cochin':0,
# 'Banglore':1,
# 'Delhi':2,
# 'New Delhi':3,
# 'Hyderabad':4,
# 'Kolkata':5

# %%
data.replace({'Destination':{'Cochin':0,
'Banglore':1,
'Delhi':2,
'New Delhi':3,
'Hyderabad':4,
'Kolkata':5 }},inplace=True)

# %%
data.head()
# Out:
#    Airline Date_of_Journey  Source  Destination                  Route  \
# 0        1      24/03/2019       2            3              BLR ? DEL
# 1        2       1/05/2019       1            1  CCU ? IXR ? BBI ? BLR
# 2        0       9/06/2019       0            0  DEL ? LKO ? BOM ? COK
# 3        1      12/05/2019       1            1        CCU ? NAG ? BLR
# 4        1      01/03/2019       2            3        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
data.replace({'Total_Stops':{'1 stop':0,
'non-stop':1,
'2 stops':2,
'3 stops':3,
'4 stops':4        }},inplace=True)

# %%
data.head()
# Out:
#    Airline Date_of_Journey  Source  Destination                  Route  \
# 0        1      24/03/2019       2            3              BLR ? DEL
# 1        2       1/05/2019       1            1  CCU ? IXR ? BBI ? BLR
# 2        0       9/06/2019       0            0  DEL ? LKO ? BOM ? COK
# 3        1      12/05/2019       1            1        CCU ? NAG ? BLR
# 4        1      01/03/2019       2            3        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration  Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m            1         No info   3897
# 1    05:50         13:15   7h 25m            2         No info   7662
# 2    09:25  04:25 10 Jun      19h            2         No info  13882
# 3    18:05         23:30   5h 25m            0         No info   6218
# 4    16:50         21:35   4h 45m            0         No info  13302

# %%
data.replace({'Additional_Info':{'No info':0,
'In-flight meal not included':1,
'No check-in baggage included':2,
'1 Long layover':3,
'Change airports':4,
'Business class':5,
'No Info':6,
'1 Short layover':7,
'Red-eye flight':8,
'2 Long layover':9}},inplace=True)

# %%
data.head()
# Out:
#    Airline Date_of_Journey  Source  Destination                  Route  \
# 0        1      24/03/2019       2            3              BLR ? DEL
# 1        2       1/05/2019       1            1  CCU ? IXR ? BBI ? BLR
# 2        0       9/06/2019       0            0  DEL ? LKO ? BOM ? COK
# 3        1      12/05/2019       1            1        CCU ? NAG ? BLR
# 4        1      01/03/2019       2            3        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration  Total_Stops  Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m            1                0   3897
# 1    05:50         13:15   7h 25m            2                0   7662
# 2    09:25  04:25 10 Jun      19h            2                0  13882
# 3    18:05         23:30   5h 25m            0                0   6218
# 4    16:50         21:35   4h 45m            0                0  13302

# %%
x=data.drop(['Date_of_Journey','Route','Dep_Time',	'Arrival_Time','Additional_Info','Price','Duration'],axis=1)
y=data['Price']

# %%
print(x)
# Out:
#        Airline  Source  Destination  Total_Stops
# 0            1       2            3            1
# 1            2       1            1            2
# 2            0       0            0            2
# 3            1       1            1            0
# 4            1       2            3            0
# ...        ...     ...          ...          ...
# 10678        6       1            1            1
# 10679        2       1            1            1
# 10680        0       2            2            1
# 10681        5       2            3            1
# 10682        2       0            0            2
#
# [10682 rows x 4 columns]

# %%
print(y)
# Out:
# 0         3897
# 1         7662
# 2        13882
# 3         6218
# 4        13302
#          ...
# 10678     4107
# 10679     4145
# 10680     7229
# 10681    12648
# 10682    11753
# Name: Price, Length: 10682, dtype: int64

# %% [markdown]
# train-test Split:

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=1)

# %%
model=Lasso()
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
model.fit(x_train,y_train)
# Out:
# Lasso()

# %%
train_predict=model.predict(x_train)
error_score=metrics.r2_score(y_train,train_predict)
print(error_score)
# Out:
# 0.254485779785772

# %%
model.fit(x_test,y_test)
test_predict=model.predict(x_test)
error_score=metrics.r2_score(y_test,test_predict)
print(error_score)
# Out:
# 0.26506089003678435

# %%
score = model.score(x_test, y_test)
print('Test Accuracy Score', score)
# Out:
# Test Accuracy Score 0.26506089003678435

# %%
new=(2,0,0,2)
new_np=np.asarray(new)
new_reshape=new_np.reshape(1,-1)
cost=model.predict(new_reshape)
print("Predcited Price by Cosidering Airline,Source,Destintaion and Total number of stops is:",cost)
# Out:
# Predcited Price by Cosidering Airline,Source,Destintaion and Total number of stops is: [10667.64844793]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
